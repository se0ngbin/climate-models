# %%
from pathlib import Path
import torch

path = Path("/data0/datasets/weatherbench/data/esgf/cmip6/pre-regrided")   # replace with path

# %%
import xarray as xr

import sys
sys.path.insert(0, '/home/seongbin/climate_tutorial')

# %%
from climate_tutorial.utils.data import load_dataset, view

t_dataset = load_dataset(path/"temperature")
t_dataset
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 241060, plev: 28, lat: 192, bnds: 2, lon: 384)
# Coordinates:
#   * time      (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
#   * plev      (plev) float64 1e+05 9.75e+04 9.5e+04 ... 1.25e+04 1e+04 5e+03
#   * lat       (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon       (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (time, lat, bnds) float64 dask.array<chunksize=(7304, 192, 2), meta=np.ndarray>
#     lon_bnds  (time, lon, bnds) float64 dask.array<chunksize=(7304, 384, 2), meta=np.ndarray>
#     ta        (time, plev, lat, lon) float32 dask.array<chunksize=(7304, 28, 192, 384), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
# ...

# %%
t_dataset.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 241060 ;
# 	plev = 28 ;
# 	lat = 192 ;
# 	bnds = 2 ;
# 	lon = 384 ;
#
# variables:
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
# 	float64 plev(plev) ;
# 		plev:units = Pa ;
# 		plev:axis = Z ;
# 		plev:positive = down ;
# 		plev:long_name = pressure ;
# 		plev:standard_name = air_pressure ;
# 	float64 lat(lat) ;
# 		lat:bounds = lat_bnds ;
# 		lat:units = degrees_north ;
# 		lat:axis = Y ;
# 		lat:long_name = Latitude ;
# 		lat:standard_name = latitude ;
# 	float64 lat_bnds(time, lat, bnds) ;
# 	float64 lon(lon) ;
# 		lon:bounds = lon_bnds ;
# 		lon:units = degrees_east ;
# 		lon:axis = X ;
# 		lon:long_name = Longitude ;
# 		lon:standard_name = longitude ;
# 	float64 lon_bnds(time, lon, bnds) ;
# 	float32 ta(time, plev, lat, lon) ;
# 		ta:standard_name = air_temperature ;
# 		ta:long_name = Air Temperature ;
# 		ta:comment = Air Temperature ;
# 		ta:units = K ;
# ...

# %%
era5_path = Path("/data0/datasets/weatherbench/data/weatherbench/era5/5.625")
era5_tdataset = load_dataset(era5_path/"temperature_850")

# %%
era5_tdataset
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 64, lat: 32, time: 350640)
# Coordinates:
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
#     level    int32 850
#   * time     (time) datetime64[ns] 1979-01-01 ... 2018-12-31T23:00:00
# Data variables:
#     t        (time, lat, lon) float32 dask.array<chunksize=(8760, 32, 64), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2019-11-21 05:02:47 GMT by grib_to_netcdf-2.14.0: /opt/ecmw...

# %%
from climate_tutorial.data import regrid

# %%
new_dataset = regrid(t_dataset, 5.625)
# Out:
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
#   * plev     (plev) float64 1e+05 9.75e+04 9.5e+04 ... 1.25e+04 1e+04 5e+03
#   * lat      (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon      (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
# Reuse existing file: bilinear_192x384_32x64_peri.nc
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# using dimensions ('lat', 'lon') from data variable ta as the horizontal dimensions for this dataset.
# ...

# %%
new_dataset
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 241060, plev: 28, lat: 32, lon: 64)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
#   * plev     (plev) float64 1e+05 9.75e+04 9.5e+04 ... 1.25e+04 1e+04 5e+03
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
# Data variables:
#     ta       (time, plev, lat, lon) float32 dask.array<chunksize=(500, 28, 32, 64), meta=np.ndarray>
# Attributes: (12/48)
#     regrid_method:          bilinear
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     ...                     ...
#     title:                  MPI-ESM1-2-HR output prepared for CMIP6
#     variable_id:            ta
#     variant_label:          r1i1p1f1
# ...

# %%
new_dataset.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:  (time: 241060, plev: 28, lat: 32, lon: 64)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
#   * plev     (plev) float64 1e+05 9.75e+04 9.5e+04 ... 1.25e+04 1e+04 5e+03
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
# Data variables:
#     ta       (time, plev, lat, lon) float32 dask.array<chunksize=(500, 28, 32, 64), meta=np.ndarray>
# Attributes: (12/48)
#     regrid_method:          bilinear
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     ...                     ...
#     title:                  MPI-ESM1-2-HR output prepared for CMIP6
#     variable_id:            ta
#     variant_label:          r1i1p1f1
# ...

# %%
era5_tdataset.time
# Out:
# <xarray.DataArray 'time' (time: 350640)>
# array(['1979-01-01T00:00:00.000000000', '1979-01-01T01:00:00.000000000',
#        '1979-01-01T02:00:00.000000000', ..., '2018-12-31T21:00:00.000000000',
#        '2018-12-31T22:00:00.000000000', '2018-12-31T23:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     level    int32 850
#   * time     (time) datetime64[ns] 1979-01-01 ... 2018-12-31T23:00:00
# Attributes:
#     long_name:  time

# %%
ds_out.time
# Out:
# <xarray.DataArray 'time' (time: 241060)>
# array(['1850-01-01T06:00:00.000000000', '1850-01-01T12:00:00.000000000',
#        '1850-01-01T18:00:00.000000000', ..., '2014-12-31T12:00:00.000000000',
#        '2014-12-31T18:00:00.000000000', '2015-01-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %%
era5_tdataset.t
# Out:
# <xarray.DataArray 't' (time: 350640, lat: 32, lon: 64)>
# dask.array<concatenate, shape=(350640, 32, 64), dtype=float32, chunksize=(8784, 32, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
#     level    int32 850
#   * time     (time) datetime64[ns] 1979-01-01 ... 2018-12-31T23:00:00
# Attributes:
#     units:          K
#     long_name:      Temperature
#     standard_name:  air_temperature

# %%
new_dataset.ta
# Out:
# <xarray.DataArray 'ta' (time: 241060, plev: 28, lat: 32, lon: 64)>
# dask.array<concatenate, shape=(241060, 28, 32, 64), dtype=float32, chunksize=(500, 28, 32, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-01T06:00:00 ... 2015-01-01
#   * plev     (plev) float64 1e+05 9.75e+04 9.5e+04 ... 1.25e+04 1e+04 5e+03
#   * lon      (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Air Temperature
#     comment:        Air Temperature
#     units:          K
#     cell_methods:   area: mean time: point
#     cell_measures:  area: areacella
#     history:        2020-03-27T11:24:36Z altered by CMOR: Reordered dimension...

# %%
new_dataset.ta.mean()
# Out:
# <xarray.DataArray 'ta' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>

# %%
new_dataset.ta??

# %%
new_dataset.ta.sel(time='1850-01-01 06:00:00', plev='1e+05', lon=5.625).head()
# Out:
# <xarray.DataArray 'ta' (lat: 5)>
# dask.array<getitem, shape=(5,), dtype=float32, chunksize=(5,), chunktype=numpy.ndarray>
# Coordinates:
#     time     datetime64[ns] 1850-01-01T06:00:00
#     plev     float64 1e+05
#     lon      float64 5.625
#   * lat      (lat) float64 -87.19 -81.56 -75.94 -70.31 -64.69
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Air Temperature
#     comment:        Air Temperature
#     units:          K
#     cell_methods:   area: mean time: point
#     cell_measures:  area: areacella
#     history:        2020-03-27T11:24:36Z altered by CMOR: Reordered dimension...
